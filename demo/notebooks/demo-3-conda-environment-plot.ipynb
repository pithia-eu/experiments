# %%
# !cat demo-3-running-the-ACE-plotter-from-terminal.txt
# Out:
# Running the ACE plotter from terminal:
# (base)jovyan@jupyter-u1:~/u1/pithia/demo/ACE/bin$ conda activate ace
# (ace) jovyan@jupyter-u1:~/u1/pithia/demo/ACE/bin$ ls
# acebin.py  oper.py  plotter.py  queries.py  test
# (ace) jovyan@jupyter-u1:~/u1/pithia/demo/ACE/bin$ python plotter.py 2019-05-14 2019-05-15
# INFO - Plotting data for [2019-05-14T00:00:00 2019-05-15T00:00:00] - 09:16:36
# (ace) jovyan@jupyter-u1:~/u1/pithia/demo/ACE/bin$

# %%
# !ls /home/jovyan/u1/pithia/demo/ACE/var/data/plots
# Out:
# magdata_20190514T000000_20190515T000000.png
# magdata_20190514T000000_20190516T000000.png
# magdata_20190514T000000_20190615T000000.png
# magdata_20190514T000000_20190715T000000.png
# magdata_20210325T000000_20210326T000000.png
# magdata_20210325T000000_20210401T000000.png

# %%
from IPython.display import Image
Image("/home/jovyan/u1/pithia/demo/ACE/var/data/plots/magdata_20190514T000000_20190515T000000.png")
