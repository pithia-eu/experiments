# %% [markdown]
# Working with ACE model from Jupyter Console

# %%
# !cat demo-1-working-with-terminal.txt
# Out:
# (ace) jovyan@jupyter-u1:~/u1/pithia/demo/ACE/var/data/plots$ ssh model@ace
# model@ace's password:
# Welcome to Alpine!
#
# The Alpine Wiki contains a large amount of how-to guides and general
# information about administrating Alpine systems.
# See <http://wiki.alpinelinux.org/>.
#
# You can setup the system with the command: setup-alpine
#
# You may change this message by editing /etc/motd.
#
# ace-b4bb87cff-z5n4h:~$ ls
# ACE       ace.log   ace.sh    init.log  init.sh
# ace-b4bb87cff-z5n4h:~$ head ace.log
# Starting ACE model.
# Tue Mar 30 19:50:00 UTC 2021
# -----------------------------------
# Cannot run the model.
# Tue Mar 30 19:59:49 UTC 2021
# -----------------------------------
# Cannot run the model.
# Tue Mar 30 20:00:00 UTC 2021
# -----------------------------------
# Cannot run the model.
# ace-b4bb87cff-z5n4h:~$ tail ace.log
# -----------------------------------
# Check for results
# Tue Apr  6 09:30:02 UTC 2021
# -----------------------------------
# ...

# %%
# !cat demo-1-copying-log-file-with-scp.txt
# Out:
# (ace) jovyan@jupyter-u1:~/u1$ scp model@ace:ace.log ace.log
# model@ace's password:
# ace.log                                                                                  100%  311KB  14.8MB/s   00:00
# (ace) jovyan@jupyter-u1:~/u1$
# (ace) jovyan@jupyter-u1:~/u1$ scp model@ace:init.log init.log
# model@ace's password:
# init.log                                                                                 100%  259KB  13.8MB/s   00:00
# (ace) jovyan@jupyter-u1:~/u1$

# %%
# !head init.log
# Out:
# MySQL is down.
# Tue Mar 30 19:48:25 UTC 2021
# -----------------------------------
# MySQL is down.
# Tue Mar 30 19:48:25 UTC 2021
# -----------------------------------
# MySQL is down.
# Tue Mar 30 19:48:25 UTC 2021
# -----------------------------------
# MySQL is down.

# %%
# !tail init.log
# Out:
# Tue Mar 30 19:48:55 UTC 2021
# -----------------------------------
# MySQL is down.
# Tue Mar 30 19:48:55 UTC 2021
# -----------------------------------
# MySQL is up. Trying to create the database.
# Tue Mar 30 19:48:55 UTC 2021
# Completed, check DB status.
# Tue Mar 30 19:48:57 UTC 2021
# -----------------------------------

# %%
# !cat ace.log
# Out:
# Starting ACE model.
# Tue Mar 30 19:50:00 UTC 2021
# -----------------------------------
# Cannot run the model.
# Tue Mar 30 19:59:49 UTC 2021
# -----------------------------------
# Cannot run the model.
# Tue Mar 30 20:00:00 UTC 2021
# -----------------------------------
# Cannot run the model.
# Tue Mar 30 20:05:00 UTC 2021
# -----------------------------------
# Cannot run the model.
# Tue Mar 30 20:10:00 UTC 2021
# -----------------------------------
# Cannot run the model.
# Tue Mar 30 20:15:00 UTC 2021
# -----------------------------------
# Cannot run the model.
# Tue Mar 30 20:20:00 UTC 2021
# -----------------------------------
# Cannot run the model.
# Tue Mar 30 20:25:00 UTC 2021
# -----------------------------------
# Cannot run the model.
# Tue Mar 30 20:30:00 UTC 2021
# -----------------------------------
# Check for results
# Tue Mar 30 20:33:38 UTC 2021
# -----------------------------------
# Starting ACE model.
# Tue Mar 30 20:35:00 UTC 2021
# ...
